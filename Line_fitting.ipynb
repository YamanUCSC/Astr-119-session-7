# %% [markdown]
# # Example of performing linear least square fitting

# %% [markdown]
# First we import numpy and matplotlib as usal

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/font_manager.py:229: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# Now, lets generate some random data about a trend line.

# %%
#set a random number seed 
np.random.seed(119)

#set number of data points 
npoints = 50 

#set x 
x = np.linspace(0,10.,npoints)

#set slope, intercept, and scatter rms 
m = 2.0
b = 1.0
sigma = 2.0 

#generate y points 
y = m*x + b + np.random.normal(scale=sigma,size=npoints)
y_err = np.full(npoints,sigma)

# %% [markdown]
# ## Let's just plot the data first

# %%
f = plt.figure(figsize=(7,7))
plt.errorbar(x,y,sigma,fmt='o')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Method #1, polyfit()

# %%
m_fit, b_fit = np.poly1d(np.polyfit(x, y, 1, w=1./y_err))    #weight with uncertainties 
print(m_fit, b_fit)

y_fit = m_fit * x + b_fit
# Out:
# 1.9634043470399505 1.283010681296193

# %% [markdown]
#  Plot result

# %%
f = plt.figure(figsize=(7,7))
plt.errorbar(x,y,yerr=y_err,fmt='o',label='data')
plt.plot(x,y_fit,label='fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=2,frameon=False)

# %% [markdown]
# ## Method 2, scipy + optimize

# %%
#import optimize from scipy 
from scipy import optimize 

#define the fucntion to fit 
def f_line(x, m, b):
    return m*x + b 

#perform the fit 
params, params_cov = optimize.curve_fit(f_line,x,y,sigma=y_err)

m_fit = params[0]
b_fit = params[1]
print(m_fit,b_fit)
# Out:
# 1.9634043457508432 1.2830106890542259

# %% [markdown]
# Plot the result

# %%
f = plt.figure(figsize=(7,7))
plt.errorbar(x,y,yerr=y_err,fmt='o',label='data')
plt.plot(x,y_fit,label='fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=2,frameon=False)

# %% [markdown]
# # We can perform much more complicated fits...

# %%
#redefine x and y 
npoints = 50 
x = np.linspace(0.,2*np.pi,npoints)

#make y a complicated function 
a = 3.4
b = 2.1
c = 0.25
d = -1.3
sig = 0.6 

y = a *np.sin( b*x + c) + d +np.random.normal(scale=sig,size=npoints)

f = plt.figure(figsize=(7,7))
plt.errorbar(x,y,yerr=y_err,fmt='o')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Perform a fit using scipy.optimize.curve_fit()

# %%
#import optimize from scipy 
from scipy import optimize 

#define the function to fit 
def f_line(x, a, b, c, d):
    return a * np.sin( b*x +c) + d

#perform the fit 
params, params_cov = optimize.curve_fit(f_line,x,y,sigma=y_err,p0=[1,2.,0.1,-0.1])

a_fit = params[0]
b_fit = params[1]
c_fit = params[2]
d_fit = params[3]

print(a_fit,b_fit,c_fit,d_fit)

y_fit = a_fit * np.sin(b_fit * x + c_fit) + d_fit
# Out:
# 3.4864431851833415 2.0984074702848696 0.2309446507620552 -1.3319606030383153

# %% [markdown]
# Plot the fit

# %%
f = plt.figure(figsize=(7,7))
plt.errorbar(x,y,yerr=y_err,fmt='o',label='data')
plt.plot(x,y_fit,label='fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=0,frameon=False)
